# %%
pip install mysql-connector-python
# Out:
# ...
#    ---------------------------------------- 0.0/16.4 MB ? eta -:--:--
#    ---- ----------------------------------- 1.8/16.4 MB 11.7 MB/s eta 0:00:02
#    ---------- ----------------------------- 4.2/16.4 MB 11.8 MB/s eta 0:00:02
#    ---------------- ----------------------- 6.8/16.4 MB 11.7 MB/s eta 0:00:01
#    ----------------------- ---------------- 9.4/16.4 MB 11.8 MB/s eta 0:00:01
#    ---------------------------- ----------- 11.8/16.4 MB 11.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 14.4/16.4 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------------  16.3/16.4 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------- 16.4/16.4 MB 10.2 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
mysqld –install
# Out:
#   Cell In[5], line 1
#     mysqld –install
#            ^
# SyntaxError: invalid character '–' (U+2013)

# %%
import mysql.connector
db=mysql.connector.connect(
    host="localhost",
    user="root",
    password="root",
    database="student"
)
print(db)
#db.close()

# %%
if db.is_connected():
    print("Connection Established")
else:
    print("unestablished")
# Out:
# Connection Established

# %%
a=db.cursor()
a.execute("create database Guaranga")

# %%
# import mysql.connector
# db=mysql.connector.connect(
#     host="localhost",
#     user="root",
#     password="root",
#     database="student"
# )
# print(db)
# a=db.cursor()
# a.execute("create database Guaranga1")
#db.close()
data= """create table mydata1(
            id int primary key,
            name varchar(20),
            course varchar(20),
            Fee int)"""
a.execute(data)

# %%
insert_table="""insert into mydata(id,name,course,fee) values
                (1,"nisha","Python", "10000")"""
a.execute(insert_table)
db.commit()

# %%
import pymysql
import turtle

try:
    import mysql.connector
    db=pymysql.connect(
        host="localhost",
        user="root",
        password="root",
        database="student"
    )
    print(db)
    # db.close()

    # a=db.cursor()
    # a.execute("use  Guaranga10")

    # data= """create table mydata(
    #             id int auto_increament primary key,
    #             name varchar(20),
    #             course varchar(20),
    #             fee int)"""
    screen=turtle.Screen()
    name=screen.textinput("User Form","Enter Your Name:")
    course=screen.textinput("User Form","Enter Your Course")
    fee=screen.textinput("User Form","Enter Your Fee")
    sql="INSERT INTO users (name, course, fee) VALUES (%s, %s ,%s)"
    a.execute(sql,(name, course, fee))
    # insert_table="""insert into mydata(id,name,course,fee) values
    #                 (1,"nisha","Python", "10000")"""
    a.execute(insert_table)
    db.commit()
    turtle.penup()
    turtle.hideturtle()
    turtle.write("Saved to MYSQL!!!", align="center", font=("Times New Roman",16,"Bold"))
    turtle.done()

except Exception as e:
    print("ERROR:",e)

finally:
    if 'db'in locals():
        db.close()
# Out:
# ...
# ERROR: (0, '')
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# Cell In[7], line 43
#      41 finally:
#      42     if 'db'in locals():
# ---> 43         db.close()
#
# File c:\Users\Mamta Aluria\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymysql\connections.py:414, in Connection.close(self)
#     405 """
#     406 Send the quit message and close the socket.
#     407
#    (...)    411 :raise Error: If the connection is already closed.
#     412 """
#     413 if self._closed:
# --> 414     raise err.Error("Already closed")
#     415 self._closed = True
#     416 if self._sock is None:
#
# Error: Already closed
